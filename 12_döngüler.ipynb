# %% [markdown]
# DÖNGÜ NEDİR?

# %% [markdown]
# Döngü: Aynı işlemi tekrar tekrar yapmak için kullanılan yapıdır.

# %% [markdown]
# Amaç:

# %% [markdown]
# Çoklu veri üzerinde işlem yapma

# %% [markdown]
# Sayaç, liste, string gibi yapıları dolaşmak

# %% [markdown]
# Örnek fikir: “1’den 10’a kadar sayıları yazdır.”

# %%
Python’da Döngü Türleri

Python’da iki temel döngü vardır:

for döngüsü

while döngüsü
