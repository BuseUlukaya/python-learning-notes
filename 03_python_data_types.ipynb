# %% [markdown]
# DATA TYPES
#
# Text Type → str
#
# Numeric Types → int, float, complex
#
# Sequence Types → list, tuple, range
#
# Mapping Type → dict
#
# Set Types → set, frozenset
#
# Boolean Type → bool
#
# Binary Types → bytes, bytearray, memoryview
#
# None Type → NoneType

# %%
name = "Buse" #str data type

# %%
age = 21 #int data type

# %%
height = 1.59 #float data type

# %%
comp = 2j #complex data type

# %%
mylist = ["Appple", "Grape", "Banana"] #list data type(İndeksleri değiştirilebilir.)

# %%
myTuple = (10, 20, 30, 40, 50) #tuple data type(İndeksleri değiştirilemez.)

# %%
myRange = range(7) #range data type(0-1-2-3-4-5-6)

# %%
myDict = {"name" : "Buse", "age" : 21} #dict data type(Key-Value)

# %%
myDict
# Out:
# {'name': 'Buse', 'age': 21}

# %%
mySet = {"Watermelon", "Cherry", "Banana"} # set data type

# %%
mySet
# Out:
# {'Banana', 'Cherry', 'Watermelon'}

# %%
myFrozenSet = {"Watermelon", "Cherry", "Banana"} #frozenset data type (İndekslerini değiştirmek sete göre daha zor.)

# %%
myFrozenSet
# Out:
# {'Banana', 'Cherry', 'Watermelon'}

# %%
myBool = True #bool data type (True-False)

# %%
x = None #none data type(Null)

# %% [markdown]
# Binary Types

# %%
import sys
x = 7
print(sys.getsizeof(x))
# Out:
# 28

# %% [markdown]
# Belirtilen komut veri türünün ramde ne kadar yer kapladığını öğrenmemizi sağlar.

# %%
name = b"python" #bytes data type

# %%
type(name)
# Out:
# bytes

# %%
print(name)
# Out:
# b'python'

# %% [markdown]
# Bytes kullanım amaçları
# Dosya okuma / yazma
#
# Ağ programlama
#
# Encoding / decoding işlemleri

# %%
name = bytearray([65])

# %%
print(name)
# Out:
# bytearray(b'A')

# %% [markdown]
# bytearray verdiğimiz değerin ASCII karşılığını getirir.

# %% [markdown]
# memoryview bellek bloklarına doğrudan erişmemizi sağlayan programlama arayüzü sağlıyor.Bununla pythonda programların bellek tüketimini izlemek ve gerekli durumda optimize etmek için kullanıyoruz. Ayrıca memoryview programcılara bellek üzerinde veri analizi yapma olasılığı sağlar. Bunu sayesinde python programları daha verimli şekilde çalıştırabilir. Özellikle bilimsel hesaplamalarda, veri analizinde , medya işleme gibi karmaşık işlerde kullanılır.

# %%
name = memoryview(bytes(5))

# %%
print(name)

# %% [markdown]
# Amaç ram ile daha hızlı etkileşime girmek, hafızayı daha etkili kullanabilmektir.
