# %%
first_number = 70
second_number = 80
if first_number > second_number:
    print("First number is greater than second number.")
elif second_number > first_number:
    print("Second number is gerater than first number")
else:
    print("Numbers are equal")
# Out:
# Second number is gerater than first number

# %% [markdown]
# Program üstten alta doğru kontrol eder:

# %% [markdown]
# If koşuluna bakar.

# %% [markdown]
# Doğruysa → bloğu çalıştırır, çıkar.

# %% [markdown]
# Yanlışsa → elif’e geçer.

# %% [markdown]
# Hiçbiri doğru değilse → else çalışır.

# %% [markdown]
# Yani: İlk doğru koşul bulunur ve sadece o çalışır.
