# %% [markdown]
# Python popüler bir programlama dilidir. Guido van Rossum tarafından yaratılmış ve 1991'de yayınlanmıştır.

# %% [markdown]
# Matematiksel Hesaplamalar
# NumPy, SciPy gibi kütüphaneler bilimsel hesaplamalar için yaygın olarak kullanılır.

# %% [markdown]
# Veri Analizi
# Pandas, NumPy ve Matplotlib gibi kütüphaneler sayesinde veri setleri üzerinde kolayca analiz yapılabilir.

# %% [markdown]
# Makine Öğrenimi
# TensorFlow, Keras, Scikit-learn gibi kütüphaneler makine öğrenimi modelleri geliştirmek için kullanılır.

# %% [markdown]
# Web Geliştirme
# Python, Django ve Flask gibi popüler web framework’leri ile web siteleri geliştirmek için kullanılabilir.

# %% [markdown]
# Otomasyon ve Betik Yazımı
# Python, tekrar eden görevleri otomatikleştirmek ve sistem üzerinde komut dosyaları çalıştırmak için idealdir.
# Örneğin, dosya işlemleri, veri kazıma (web scraping), e-posta gönderimi gibi işlemler otomatikleştirilebilir.

# %% [markdown]
# Veritabanı İşlemleri
# Python ile veritabanlarına (MySQL, PostgreSQL, SQLite gibi) bağlanabilir ve veri çekme, ekleme, güncelleme gibi işlemler yapılabilir.

# %% [markdown]
# API ile Entegrasyon
# Python, REST API’ler ile iletişim kurmak, veri çekmek ve veri göndermek için kullanılabilir.

# %% [markdown]
# Görsel ve Grafik İşleme
# OpenCV, PIL (Pillow) gibi kütüphanelerle görsel işlemler yapılabilir. Görüntü analizleri, filtreleme ve grafiksel düzenlemeler mümkündür.

# %% [markdown]
# Oyun Geliştirme
# Pygame gibi kütüphanelerle basit oyunlar geliştirebilirsiniz.

# %% [markdown]
# Yapay Zeka
# Doğal dil işleme, görüntü işleme, derin öğrenme gibi yapay zeka alanlarında Python çok güçlüdür.
# Keras, PyTorch gibi kütüphaneler bu alanda sıkça kullanılır.

# %% [markdown]
# Pythonda yorum satırı için # kullanılır.

# %% [markdown]
# Printin içerisinde tek tırnak ya da çift tırnak kullanılabilir.Ancak tek tırnak zaten kullanılacaksa o zaman kullanımı hata verir.

# %% [markdown]
# Ayrıca pythonda girinti kullanımı çok önemlidir.Yanlış girinti kullanımında python hata verir.

# %% [markdown]
# Çoklu yarım satırı yapmak için """ 3 tane çift tırnak kullanabiliriz. Ancak çok da güzel bir yöntem değildir.
