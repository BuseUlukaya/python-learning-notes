# %% [markdown]
# Veri türünü zorunlu olarak belirtmemiz gereken yerler ve zorunlu olarak tür dönüşümü yapılması gerektiren durumlar var.

# %%
x = True

# %%
type(x)
# Out:
# bool

# %%
x = str(True)

# %%
type(x)
# Out:
# str

# %%
y = int(7.19)

# %%
type(y)
# Out:
# int

# %%
y
# Out:
# 7

# %%
z = int(True)

# %%
type(z)
# Out:
# int

# %%
z
# Out:
# 1

# %% [markdown]
# Ama metinsel ifadenin sayıya  dönüştürülmesi gibi gerçekleştirilmesi mümkün olmayan durumlara oldukça dikkat edilmelidir.
