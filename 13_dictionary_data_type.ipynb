# %% [markdown]
# DICTIONARY

# %% [markdown]
# key-value pairing

# %%
fruit_list = ["banana", "orange"]

# %%
calorie_list = [100, 150]

# %%
fruit_list[0]
# Out:
# 'banana'

# %%
calorie_list[0]
# Out:
# 100

# %%
fitness_dictionary = {"banana":100, "orange":150 }

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
fitness_dictionary.keys()
# Out:
# dict_keys(['banana', 'orange'])

# %%
fitness_dictionary.values()
# Out:
# dict_values([100, 150])

# %%
type(fitness_dictionary.keys())
# Out:
# dict_keys

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
list(fitness_dictionary.keys())
# Out:
# ['banana', 'orange']

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
fitness_dictionary["banana"] = 200

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'orange': 150}

# %%
fitness_dictionary["melon"] = 300

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'orange': 150, 'melon': 300}

# %% [markdown]
# Dictionary yapısında key-value ilişkisi vardır. Index mantığı yoktur.

# %%
fitness_dictionary.get("apple", 0)
# Out:
# 0

# %%
fitness_dictionary.get("banana", 0)
# Out:
# 200

# %%
my_mixed_dictionary = {"key1": 100, "key2": 3.14, "key3": [10, 20, 30] }

# %%
my_mixed_dictionary["key3"][1]
# Out:
# 20

# %%
last_dictionary = { "k1": 10, "k2":[10, 20, 30, 40, 50], "k3": "string", "k4": {"a": 100, "b":200} }

# %%
last_dictionary["k4"]["b"]
# Out:
# 200

# %%
last_dictionary["k2"][3]
# Out:
# 40
