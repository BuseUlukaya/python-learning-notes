# %% [markdown]
# Unicode Karakter Sistemi

# %% [markdown]
# Bazı karakterler 1 byteden fazla yer kaplar. 1byte yeterli olmadığı anlaşılınca ASCII tablosu görevi Unicode'de devretti.

# %% [markdown]
# Bugün modern sistemlerde kullanılan ana sistem: Unicode

# %% [markdown]
# Unicode: Dünyadaki neredeyse tüm dillerin karakterlerinin her birine benzersiz bir sayı verir.
